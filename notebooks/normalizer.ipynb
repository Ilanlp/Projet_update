# %%
import pandas as pd

azuna_df = pd.read_csv("./../data/azuna_jobs_2025.csv")
azuna_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      250 non-null    int64
#  1   source                  250 non-null    object
#  2   title                   250 non-null    object
#  3   description             250 non-null    object
#  4   company_name            250 non-null    object
#  5   location_name           250 non-null    object
#  6   latitude                230 non-null    float64
#  7   longitude               230 non-null    float64
#  8   date_created            250 non-null    object
#  9   date_updated            250 non-null    object
#  10  contract_type           93 non-null     object
#  11  contract_duration       0 non-null      float64
#  12  working_hours           6 non-null      object
#  13  salary_min              79 non-null     float64
# ...

# %%
azuna_df.describe()
# Out:
#                  id    latitude   longitude  contract_duration    salary_min  \
# count  2.500000e+02  230.000000  230.000000                0.0     79.000000
# mean   5.155128e+09   47.159054    2.738471                NaN  34025.316456
# std    9.680871e+04    2.180276    2.314089                NaN   9688.712285
# min    5.155047e+09   42.702140   -4.172963                NaN  22000.000000
# 25%    5.155050e+09   45.441505    2.257570                NaN  27000.000000
# 50%    5.155055e+09   48.526510    2.344631                NaN  33000.000000
# 75%    5.155256e+09   48.863839    4.360860                NaN  37500.000000
# max    5.155257e+09   50.638900    9.450750                NaN  70000.000000
#
#          salary_max  experience_required  sector  skills  remote_work  \
# count     79.000000                  0.0     0.0     0.0          0.0
# mean   41025.316456                  NaN     NaN     NaN          NaN
# ...

# %%
france_travail = pd.read_csv("./../data/france_travail_jobs_1_months.csv")
france_travail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1420 entries, 0 to 1419
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1420 non-null   object
#  1   source                  1420 non-null   object
#  2   title                   1420 non-null   object
#  3   description             1420 non-null   object
#  4   company_name            814 non-null    object
#  5   location_name           1420 non-null   object
#  6   latitude                1322 non-null   float64
#  7   longitude               1322 non-null   float64
#  8   date_created            1420 non-null   object
#  9   date_updated            1420 non-null   object
#  10  contract_type           1420 non-null   object
#  11  contract_duration       1260 non-null   object
#  12  working_hours           191 non-null    object
#  13  salary_min              347 non-null    float64
# ...

# %%
france_travail.describe()
# Out:
#           latitude    longitude     salary_min     salary_max  remote_work
# count  1322.000000  1322.000000     347.000000     347.000000          0.0
# mean     45.750262     1.803748   39499.005504   48185.008271          NaN
# std       8.249165     9.989919   14305.666057   16475.182699          NaN
# min     -21.243523   -61.594891       3.920000      11.880000          NaN
# 25%      45.430195     1.367538   40000.000000   45000.000000          NaN
# 50%      48.025159     2.337887   40000.000000   50000.000000          NaN
# 75%      48.869504     4.797937   45000.000000   55000.000000          NaN
# max      51.028256    55.542606  100000.000000  100000.000000          NaN

# %%
france_travail.head()
# Out:
#         id          source                            title  \
# 0  3812955  france_travail  Directeur d'agence (RGPD) (H/F)
# 1  3812871  france_travail  Directeur d'agence (RGPD) (H/F)
# 2  3812538  france_travail  Directeur d'agence (RGPD) (H/F)
# 3  4325759  france_travail             Data scientist (H/F)
# 4  3813393  france_travail  Directeur d'agence (RGPD) (H/F)
#
#                                          description company_name  \
# 0  Rejoignez Notre Réseau de Franchise Agence RGP...  AGENCE RGPD
# 1  Rejoignez Notre Réseau de Franchise Agence RGP...  AGENCE RGPD
# 2  Rejoignez Notre Réseau de Franchise Agence RGP...  AGENCE RGPD
# 3  Description du poste : En tant qu'AutoAPI Test...          NaN
# 4  Rejoignez Notre Réseau de Franchise Agence RGP...  AGENCE RGPD
#
#               location_name   latitude  longitude               date_created  \
# 0               01 - BELLEY  45.754371   5.688373  2025-03-19 04:51:32+00:00
# ...

# %%
france_travail['langues'].unique()
# Out:
# array(['AGENCE RGPD', nan, 'CTRE DEP GESTION FONCTION PUB TERRITOR',
#        'ADSearch', 'iPepper', 'Sophia Conseil', 'DAVIDSON PACA',
#        'Simplon', 'SKYINCAP', 'BUREAU ALPES CONTROLES',
#        'Forums Talents Handicap', 'JEHANN', 'AMILTONE',
#        'RANDSTAD DIGITAL FRANCE', 'INOV TEAM LABS',
#        'CANNES EXPERTISE INFORMATIQUE', 'Adsearch',
#        'OPH TROYES AUBE HABITAT', 'OMNICIEL PROFILS ET SOLUTIONS',
#        'DGTL Performance', 'SIMPLON.CO', 'DSI France Travail', 'VIVERIS',
#        'Walter Learning - Marseille', 'ISCOD', 'Thales DIS France SAS',
#        'ENOVACOM', 'GESER BEST', 'TIL TECHNOLOGIES', 'Vulcain Services',
#        'RTE Alternance', 'Walter Learning', 'HOWMET AEROSPACE',
#        "CLINIQUE DE L'ATLANTIQUE", 'HARRY HOPE', 'ROSARA',
#        'ORIENTACTION EMPLOI', 'Safran Electronics & Defense', 'Randstad',
#        'PRODEVAL', "DÉPARTEMENT DE L'EURE",
#        'BNP Paribas Mission Handicap', 'CHR Numérique', 'NEXT DECISION',
# ...

# %%
all_jobs = pd.read_csv("./../data/all_jobs_20250421.csv")
all_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      13 non-null     object
#  1   source                  13 non-null     object
#  2   title                   13 non-null     object
#  3   description             13 non-null     object
#  4   company_name            11 non-null     object
#  5   location_name           13 non-null     object
#  6   latitude                13 non-null     float64
#  7   longitude               13 non-null     float64
#  8   date_created            2 non-null      object
#  9   date_updated            2 non-null      object
#  10  contract_type           12 non-null     object
#  11  contract_duration       9 non-null      object
#  12  working_hours           4 non-null      object
#  13  salary_min              6 non-null      float64
# ...

# %%
all_jobs.describe()
# Out:
#         latitude  longitude   salary_min    salary_max  remote_work
# count  13.000000  13.000000      6.00000      6.000000          0.0
# mean   45.275114   5.913796  18204.66500  23019.331667          NaN
# std    12.907117  12.909013  18679.80103  24576.246552          NaN
# min     2.317650   2.267032    487.00000    775.000000          NaN
# 25%    48.841620   2.341157   1535.24750   1985.247500          NaN
# 50%    48.856305   2.344631  16270.49500  18770.495000          NaN
# 75%    48.863839   2.356841  33750.00000  38750.000000          NaN
# max    48.867669  48.877479  40000.00000  58000.000000          NaN

# %%
nunique = all_jobs['company_name'].nunique(dropna=True)
print(nunique)
# Out:
# 11
